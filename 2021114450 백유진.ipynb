# %% [markdown]
# <a href="https://colab.research.google.com/github/yujin2119/web1/blob/main/2021114450%20%EB%B0%B1%EC%9C%A0%EC%A7%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **코드를 작성하고 저장하는 이름은 NA학번.ipynb로 저장하기 바랍니다.**

# %% [markdown]
# #**[문제 1] 다음 예제 7.2에 대해서 아래 [결과출력] 결과를 출력하는 파이썬 코드를 작성하시오**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [결과출력]
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **[문제 2-3] 아래 예제 4.8에 대해서 [결과출력]처럼 나오는 파이썬으로 코드를 작성하고 그림 4.9에 보이는 그래프를 그리시오.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [결과출력]
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **[문제 4-5] 아래 예제 5.6을 Solution에서 보이는 형식으로 출력하는 파이썬 코드를 작성하시오. 단, FalsePosition 방법은 수정된(개선된) 버전의 코드를 작성하여 보이시오**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
